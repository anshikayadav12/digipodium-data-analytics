# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
marks = pd.read_excel('marksheet_faked.xlsx')
marks
# Out:
#     S.no   First name   Last name  DM  SE  GFX  DBMS  ECO
# 0      1     Sandhya        Singh  60  87   34    55   79
# 1      2       Pinki        Yadav  49  73   53    51   96
# 2      3      Ankita        Verma  77  77   96    93   79
# 3      4   Dipanjali        Singh  67  36   37    89   39
# 4      5      Khushi      Awasthi  34  90   59    33   47
# 5      6     Shalini          Pal  33  64   97    59   67
# 6      7      Saloni         Gond  60  64  100    97   37
# 7      8     Anushka   Srivastava  62  44   94    89   52
# 8      9       Aditi       Pandey  30  91   63   100   84
# 9     10       Umama        Anjum  84  38   37    92   86
# 10    11      Muskan        Singh  44  58   74    81   57
# 11    12       Kajal       Pandey  83  54   40    75   30
# 12    13     Anshika        Yadav  35  55   57    73   79
# 13    14     Deepika         Soni  69  87   99    82   75
# 14    15     Srishti      Kashyap  77  75   93    62   49
# 15    16  Pratishtha        Singh  41  35   82    47   62
# 16    17     Kritika       Kumari  50  95   91    94   85
# 17    18      Shilpa        Singh  42  74   53    92   84
# 18    19       Komal       Sharma  55  73   81    93   79
# 19    20      Deepti        Singh  53  86   90    93   81

# %%
marks = pd.read_excel('marksheet_faked.xlsx')
marks
# Out:
#     S.no   First name   Last name  DM  SE  GFX  DBMS  ECO
# 0      1     Sandhya        Singh  60  87   34    55   79
# 1      2       Pinki        Yadav  49  73   53    51   96
# 2      3      Ankita        Verma  77  77   96    93   79
# 3      4   Dipanjali        Singh  67  36   37    89   39
# 4      5      Khushi      Awasthi  34  90   59    33   47
# 5      6     Shalini          Pal  33  64   97    59   67
# 6      7      Saloni         Gond  60  64  100    97   37
# 7      8     Anushka   Srivastava  62  44   94    89   52
# 8      9       Aditi       Pandey  30  91   63   100   84
# 9     10       Umama        Anjum  84  38   37    92   86
# 10    11      Muskan        Singh  44  58   74    81   57
# 11    12       Kajal       Pandey  83  54   40    75   30
# 12    13     Anshika        Yadav  35  55   57    73   79
# 13    14     Deepika         Soni  69  87   99    82   75
# 14    15     Srishti      Kashyap  77  75   93    62   49
# 15    16  Pratishtha        Singh  41  35   82    47   62
# 16    17     Kritika       Kumari  50  95   91    94   85
# 17    18      Shilpa        Singh  42  74   53    92   84
# 18    19       Komal       Sharma  55  73   81    93   79
# 19    20      Deepti        Singh  53  86   90    93   81

# %%
marks.set_index('First name', inplace=True)
marks
# Out:
#              S.no   Last name  DM  SE  GFX  DBMS  ECO
# First name
# Sandhya         1       Singh  60  87   34    55   79
# Pinki           2       Yadav  49  73   53    51   96
# Ankita          3       Verma  77  77   96    93   79
# Dipanjali       4       Singh  67  36   37    89   39
# Khushi          5     Awasthi  34  90   59    33   47
# Shalini         6         Pal  33  64   97    59   67
# Saloni          7        Gond  60  64  100    97   37
# Anushka         8  Srivastava  62  44   94    89   52
# Aditi           9      Pandey  30  91   63   100   84
# Umama          10       Anjum  84  38   37    92   86
# Muskan         11       Singh  44  58   74    81   57
# Kajal          12      Pandey  83  54   40    75   30
# Anshika        13       Yadav  35  55   57    73   79
# Deepika        14        Soni  69  87   99    82   75
# Srishti        15     Kashyap  77  75   93    62   49
# Pratishtha     16       Singh  41  35   82    47   62
# Kritika        17      Kumari  50  95   91    94   85
# Shilpa         18       Singh  42  74   53    92   84
# Komal          19      Sharma  55  73   81    93   79
# Deepti         20       Singh  53  86   90    93   81

# %%
marks[['ECO','GFX','DBMS','DM','SE']].plot(kind='area',figsize=(10,5), title='ECO Marks')
# Out:
# <Axes: title={'center': 'ECO Marks'}, xlabel='First name'>

# %%
marks.index
# Out:
# Index(['Sandhya ', 'Pinki ', 'Ankita ', 'Dipanjali ', 'Khushi ', 'Shalini ',
#        'Saloni ', 'Anushka ', 'Aditi ', 'Umama ', 'Muskan ', 'Kajal ',
#        'Anshika ', 'Deepika ', 'Srishti ', 'Pratishtha ', 'Kritika ',
#        'Shilpa ', 'Komal ', 'Deepti '],
#       dtype='object', name='First name')

# %%
marks['ECO'] # selecting a column (series)
# Out:
# First name
# Sandhya        79
# Pinki          96
# Ankita         79
# Dipanjali      39
# Khushi         47
# Shalini        67
# Saloni         37
# Anushka        52
# Aditi          84
# Umama          86
# Muskan         57
# Kajal          30
# Anshika        79
# Deepika        75
# Srishti        49
# Pratishtha     62
# Kritika        85
# Shilpa         84
# Komal          79
# Deepti         81
# Name: ECO, dtype: int64

# %%
marks
# Out:
#              S.no   Last name  DM  SE  GFX  DBMS  ECO
# First name
# Sandhya         1       Singh  60  87   34    55   79
# Pinki           2       Yadav  49  73   53    51   96
# Ankita          3       Verma  77  77   96    93   79
# Dipanjali       4       Singh  67  36   37    89   39
# Khushi          5     Awasthi  34  90   59    33   47
# Shalini         6         Pal  33  64   97    59   67
# Saloni          7        Gond  60  64  100    97   37
# Anushka         8  Srivastava  62  44   94    89   52
# Aditi           9      Pandey  30  91   63   100   84
# Umama          10       Anjum  84  38   37    92   86
# Muskan         11       Singh  44  58   74    81   57
# Kajal          12      Pandey  83  54   40    75   30
# Anshika        13       Yadav  35  55   57    73   79
# Deepika        14        Soni  69  87   99    82   75
# Srishti        15     Kashyap  77  75   93    62   49
# Pratishtha     16       Singh  41  35   82    47   62
# Kritika        17      Kumari  50  95   91    94   85
# Shilpa         18       Singh  42  74   53    92   84
# Komal          19      Sharma  55  73   81    93   79
# Deepti         20       Singh  53  86   90    93   81

# %%
marks.columns # only column name
# Out:
# Index(['S.no', 'Last name', 'DM', 'SE', 'GFX', 'DBMS', 'ECO'], dtype='object')

# %%
marks['ECO']+2
# Out:
# First name
# Sandhya        81
# Pinki          98
# Ankita         81
# Dipanjali      41
# Khushi         49
# Shalini        69
# Saloni         39
# Anushka        54
# Aditi          86
# Umama          88
# Muskan         59
# Kajal          32
# Anshika        81
# Deepika        77
# Srishti        51
# Pratishtha     64
# Kritika        87
# Shilpa         86
# Komal          81
# Deepti         83
# Name: ECO, dtype: int64

# %%
marks['ECO'] += 2 # grace marks

# %%
marks
# Out:
#              S.no   Last name  DM  SE  GFX  DBMS  ECO
# First name
# Sandhya         1       Singh  60  87   34    55   81
# Pinki           2       Yadav  49  73   53    51   98
# Ankita          3       Verma  77  77   96    93   81
# Dipanjali       4       Singh  67  36   37    89   41
# Khushi          5     Awasthi  34  90   59    33   49
# Shalini         6         Pal  33  64   97    59   69
# Saloni          7        Gond  60  64  100    97   39
# Anushka         8  Srivastava  62  44   94    89   54
# Aditi           9      Pandey  30  91   63   100   86
# Umama          10       Anjum  84  38   37    92   88
# Muskan         11       Singh  44  58   74    81   59
# Kajal          12      Pandey  83  54   40    75   32
# Anshika        13       Yadav  35  55   57    73   81
# Deepika        14        Soni  69  87   99    82   77
# Srishti        15     Kashyap  77  75   93    62   51
# Pratishtha     16       Singh  41  35   82    47   64
# Kritika        17      Kumari  50  95   91    94   87
# Shilpa         18       Singh  42  74   53    92   86
# Komal          19      Sharma  55  73   81    93   81
# Deepti         20       Singh  53  86   90    93   83

# %%
marks[['DBMS','DM']]# selecting multiple columns(dataframe)
# Out:
#              DBMS  DM
# First name
# Sandhya        55  60
# Pinki          51  49
# Ankita         93  77
# Dipanjali      89  67
# Khushi         33  34
# Shalini        59  33
# Saloni         97  60
# Anushka        89  62
# Aditi         100  30
# Umama          92  84
# Muskan         81  44
# Kajal          75  83
# Anshika        73  35
# Deepika        82  69
# Srishti        62  77
# Pratishtha     47  41
# Kritika        94  50
# Shilpa         92  42
# Komal          93  55
# Deepti         93  53

# %%
marks['total']= marks['DBMS']+ marks['DM'] + marks['ECO'] + marks['GFX'] + marks['SE']+marks['total']

# %%
marks
# Out:
#              S.no   Last name  DM  SE  GFX  DBMS  ECO  total  percentage
# First name
# Ankita          3       Verma  77  77   96    93   81    848       362.4
# Kritika        17      Kumari  50  95   91    94   87    834       341.0
# Deepika        14        Soni  69  87   99    82   77    828       344.4
# Deepti         20       Singh  53  86   90    93   83    810       336.2
# Komal          19      Sharma  55  73   81    93   81    766       324.6
# Aditi           9      Pandey  30  91   63   100   86    740       297.2
# Saloni          7        Gond  60  64  100    97   39    720       308.8
# Srishti        15     Kashyap  77  75   93    62   51    716       298.0
# Shilpa         18       Singh  42  74   53    92   86    694       287.8
# Anushka         8  Srivastava  62  44   94    89   54    686       307.8
# Umama          10       Anjum  84  38   37    92   88    678       308.6
# Pinki           2       Yadav  49  73   53    51   98    648       265.6
# Shalini         6         Pal  33  64   97    59   69    644       270.8
# Sandhya         1       Singh  60  87   34    55   81    634       247.4
# Muskan         11       Singh  44  58   74    81   59    632       269.6
# Anshika        13       Yadav  35  55   57    73   81    602       257.0
# Kajal          12      Pandey  83  54   40    75   32    568       240.8
# Dipanjali       4       Singh  67  36   37    89   41    540       241.2
# Pratishtha     16       Singh  41  35   82    47   64    538       241.0
# Khushi          5     Awasthi  34  90   59    33   49    530       193.0

# %% [markdown]
# marks

# %%
marks['total']=marks['percentage']/5

# %%
marks
# Out:
#              S.no   Last name  DM  SE  GFX  DBMS  ECO  total  percentage
# First name
# Ankita          3       Verma  77  77   96    93   81  72.48       362.4
# Kritika        17      Kumari  50  95   91    94   87  68.20       341.0
# Deepika        14        Soni  69  87   99    82   77  68.88       344.4
# Deepti         20       Singh  53  86   90    93   83  67.24       336.2
# Komal          19      Sharma  55  73   81    93   81  64.92       324.6
# Aditi           9      Pandey  30  91   63   100   86  59.44       297.2
# Saloni          7        Gond  60  64  100    97   39  61.76       308.8
# Srishti        15     Kashyap  77  75   93    62   51  59.60       298.0
# Shilpa         18       Singh  42  74   53    92   86  57.56       287.8
# Anushka         8  Srivastava  62  44   94    89   54  61.56       307.8
# Umama          10       Anjum  84  38   37    92   88  61.72       308.6
# Pinki           2       Yadav  49  73   53    51   98  53.12       265.6
# Shalini         6         Pal  33  64   97    59   69  54.16       270.8
# Sandhya         1       Singh  60  87   34    55   81  49.48       247.4
# Muskan         11       Singh  44  58   74    81   59  53.92       269.6
# Anshika        13       Yadav  35  55   57    73   81  51.40       257.0
# Kajal          12      Pandey  83  54   40    75   32  48.16       240.8
# Dipanjali       4       Singh  67  36   37    89   41  48.24       241.2
# Pratishtha     16       Singh  41  35   82    47   64  48.20       241.0
# Khushi          5     Awasthi  34  90   59    33   49  38.60       193.0

# %%
#sorting
marks.sort_values(by='total',ascending=False,inplace=True)

# %%
marks
# Out:
#              S.no   Last name  DM  SE  GFX  DBMS  ECO  total  percentage
# First name
# Ankita          3       Verma  77  77   96    93   81  72.48       362.4
# Deepika        14        Soni  69  87   99    82   77  68.88       344.4
# Kritika        17      Kumari  50  95   91    94   87  68.20       341.0
# Deepti         20       Singh  53  86   90    93   83  67.24       336.2
# Komal          19      Sharma  55  73   81    93   81  64.92       324.6
# Saloni          7        Gond  60  64  100    97   39  61.76       308.8
# Umama          10       Anjum  84  38   37    92   88  61.72       308.6
# Anushka         8  Srivastava  62  44   94    89   54  61.56       307.8
# Srishti        15     Kashyap  77  75   93    62   51  59.60       298.0
# Aditi           9      Pandey  30  91   63   100   86  59.44       297.2
# Shilpa         18       Singh  42  74   53    92   86  57.56       287.8
# Shalini         6         Pal  33  64   97    59   69  54.16       270.8
# Muskan         11       Singh  44  58   74    81   59  53.92       269.6
# Pinki           2       Yadav  49  73   53    51   98  53.12       265.6
# Anshika        13       Yadav  35  55   57    73   81  51.40       257.0
# Sandhya         1       Singh  60  87   34    55   81  49.48       247.4
# Dipanjali       4       Singh  67  36   37    89   41  48.24       241.2
# Pratishtha     16       Singh  41  35   82    47   64  48.20       241.0
# Kajal          12      Pandey  83  54   40    75   32  48.16       240.8
# Khushi          5     Awasthi  34  90   59    33   49  38.60       193.0

# %%
fig,ax = plt.subplots(figsize=(10,5), ncols=2)
marks['total'].plot(kind='bar',ax=ax[0])
cols = ['DBMS','DM','ECO','GFX','SE']
marks[cols].plot(kind='kde', ax=ax[1])
plt.show()

# %%
fig,ax = plt.subplots(figsize=(10,5), ncols=2)
marks['total'].plot(kind='bar',ax=ax[0])
marks['percentage'].plot(kind='pie', ax=ax[1])
plt.show()

# %%
marks.groupby('Last name')['total'].sum()
# Out:
# Last name
# Anjum          61.72
# Awasthi        38.60
# Gond           61.76
# Kashyap        59.60
# Kumari         68.20
# Pal            54.16
# Pandey        107.60
# Sharma         64.92
# Singh         324.64
# Soni           68.88
# Srivastava     61.56
# Verma          72.48
# Yadav         104.52
# Name: total, dtype: float64
